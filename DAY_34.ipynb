# %% [markdown]
# <a href="https://colab.research.google.com/github/Ekansh0801/90-DAYS-OF-MACHINE-LEARNING/blob/main/DAY_34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LASSO REGRESSION

# %% [markdown]
# ![WhatsApp Image 2024-11-16 at 17.03.59_4aa7c3e6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-11-16 at 16.55.37_f1cd2c33.jpg](data:image/jpeg;base64,...)
